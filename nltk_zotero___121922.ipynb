# %%
import nltk
# nltk.download('punkt')
from pyzotero import zotero
import numpy as np
import collections
import requests



def write(x,y):
    with open(x,'a') as f:
        f.write(y)
        f.write('\n')
        f.close()
    return _

# %%
len(itz)
# Out:
# 198

# %%
### 
### use this to configure with your own api key and groupnum.
###  https://pyzotero.readthedocs.io/en/latest/#getting-started-short-version


zot = zotero.Zotero(personal_id,'user',api_key)
cols = zot.collections()

# itz = zot.everything(zot.collection_items(cols[-1]['key'])) 
#not helpful here, includes multiple entries of same

itz = zot.everything(zot.collection_items_top(cols[0]['key']))
print(len(itz))

coun = 0
for idx,i in enumerate(itz):
    x = len(i['data']['abstractNote'])
    if x < 100:
        coun += 1

count = 0
for idx,i in enumerate(itz):
    x = len(i['data']['abstractNote'])
    if x < 100:
        count += 1
        print(f"{count}/{coun}")
        print(i['data']['title'])
        # print(i['data']['auth
        print(i['data']['date'])
        try:
            print(i['data']['DOI'])
        except:
            _
        try:
            print(i['data']['url'])
        except:
            _
        try:
            print(i['data']['creators'][0]['lastName'],'\n')
        except:
            _
        print('______\n')
print(coun)
# Out:
# 198
# 1/20
# Evaluation of five instream flow needs methodologies and water quantity needs of three Utah trout streams
# 1980
#
# Geer
#
# ______
#
# 2/20
# Environmental water requirements for lowland river systems on the Swan Coastal Plain
# 1996
#
#
# Davies
#
# ______
#
# 3/20
# The basic flow: an alternative approach to calculate minimum environmental instream flows
# 1996
#
#
# Palau
#
# ______
#
# 4/20
# River Allen instream flow requirements
# 1993
#
# Johnson
#
# ______
#
# 5/20
# Report on minimum flow requirements for instream habitat in Taranaki rivers
# 1993
#
# Jowett
#
# ______
#
# 6/20
# Flow regime requirements River Darent
# 1993
# https://nora.nerc.ac.uk/id/eprint/508354/
# Ladle
#
# ______
#
# 7/20
# A preliminary assessment of the relationship between angling quality and flow on the Lower Malmesbury Avon
# 1998
#
#
# Ibbotson
#
# ______
#
# 8/20
# Responses of biofilms to cyclic releases during a low flow period in the Mitta Mitta River, Victoria, Australia
# 2006
#
#
# Watts
#
# ______
#
# 9/20
# Hydrologic Manipulations of the Channelized Kissimmee River: Implications for restoration
# 1998-09-01
# 10.2307/1313338
# https://doi.org/10.2307/1313338
# Toth
#
# ______
#
# 10/20
# Environmental flow requirements of the Brisbane River downstream from Wivenhoe Dam
# 2000
#
#
# Arthington
#
# ______
#
# 11/20
# Field testing and adaptation of a methodology to measure "in-stream" values in the Tongue River, Northern Great Plains(NGP) region: executive summary
# 1977
# https://nepis.epa.gov/Exe/ZyNET.exe/94000MM7.txt?ZyActionD=ZyDocument&Client=EPA&Index=1976%20Thru%201980&Docs=&Query=&Time=&EndTime=&SearchMethod=1&TocRestrict=n&Toc=&TocEntry=&QField=&QFieldYear=&QFieldMonth=&QFieldDay=&UseQField=&IntQFieldOp=0&ExtQFieldOp=0&XmlQuery=&File=D%3A%5CZYFILES%5CINDEX%20DATA%5C76THRU80%5CTXT%5C00000038%5C94000MM7.txt&User=ANONYMOUS&Password=anonymous&SortMethod=h%7C-&MaximumDocuments=1&FuzzyDegree=0&ImageQuality=r75g8/r75g8/x150y150g16/i425&Display=hpfr&DefSeekPage=x&SearchBack=ZyActionL&Back=ZyActionS&BackDesc=Results%20page&MaximumPages=1&ZyEntry=4#
# Bovee
#
# ______
#
# 12/20
# The use of benthic invertebrate production for the definition of Ecologically Acceptable Flows in
# 2001
#
#
# Buffagni
#
# ______
#
# 13/20
# Instream flow requirements of aquatic ecology in two British rivers: application and assessment of the instream flow incremental methodology using the PHABSIM system
# 1991
#
# Bullock
#
# ______
#
# 14/20
# Report of the Broken River Scientific Panel on the environmental condition and flows of the Broken River and Broken Creek
# 2001
# https://ewater.org.au/archive/crcfe/freshwater/publications.nsf/8116917c22b76d58ca256f120027bb83/4164369b846ce43fca256f0b00217c4a02ec.html?OpenDocument
# Cotthingham
#
# ______
#
# 15/20
# Minimum acceptable stream flows in British Columbia: a review
# 1977
#
# Neuman
#
# ______
#
# 16/20
# Evaluation of instream flow methods and determination of water quantity needs for streams in the state of Colorado
# 1979
#
# Nehring
#
# ______
#
# 17/20
# Application of the Instream Flow Incremental Methodology to conservation flow for freshwater fishes in Japan
# 1996
#
#
# Tamai
#
# ______
#
# 18/20
# Opihi catchment ecological flow assessment - Google Search
#
# https://www.google.com/search?q=Opihi+catchment+ecological+flow+assessment&client=firefox-b-d&sxsrf=ALiCzsbeWrvCS5PoWsVKX1yM4vKn98MZoQ%3A1669646327754&ei=98eEY-jULfCxptQPyN6N8Ag&ved=0ahUKEwiorJCijdH7AhXwmIkEHUhvA44Q4dUDCA4&uact=5&oq=Opihi+catchment+ecological+flow+assessment&gs_lcp=Cgxnd3Mtd2l6LXNlcnAQA0oECEEYAUoECEYYAFAAWABg0QxoA3AAeACAAQCIAQCSAQCYAQCgAQLAAQE&sclient=gws-wiz-serp
# ______
#
# 19/20
# Flow recommendations for the tributaries of the Great Lakes in New York and Pennsylvania
# 2013
#
#
# Taylor
#
# ______
#
# 20/20
# Development of recommended flow targets to support biological integrity based on regional flow-ecology relationships for benthic macroinvertebrates in Southern California streams
# 2017
#
#
# Stein
#
# ______
#
# 20

# %%
A = []
for idx,_ in enumerate(range(len(itz))):
    x = itz[idx]['data']['title']
    y = itz[idx]['data']['abstractNote']
    z = [i['tag'] for i in itz[idx]['data']['tags']]
    # try:
    #     a = itz[idx]['data']['DOI']
    #     if len(a) == 0:
    #         a = 'no doi'
    # except:
    #     a = 'no doi'
    # b = itz[idx]['data']['date']
    
    A.append([x,y,z])   
A = np.asarray(A,dtype=object)
A.shape
# Out:
# (198, 3)

# %%
count0 = collections.Counter()
for idx,i in enumerate(A[:,0]):
    s1 = i.replace("'", '')
    s2 = s1.replace("?", '')
    s3 = s2.replace(".",'')
    s4 = s3.replace(",",'')
    s5 = s4.replace(":",'')
    s6 = s5.lower()
    tokens = nltk.word_tokenize(s6)
    every = nltk.everygrams(tokens,2,4)
    count0 = count0 + (collections.Counter(every))
count0 = count0.most_common()

count1 = collections.Counter()
for idx, i in enumerate(A[:,1]):
    s1 = i.replace("'", '')
    s2 = s1.replace("?", '')
    s3 = s2.replace(".",'')
    s4 = s3.replace(",",'')
    s5 = s4.replace(":",'')
    s6 = s5.lower()
    tokens = nltk.word_tokenize(s6)
    every = nltk.everygrams(tokens,2,4)
    count1 = count1 + (collections.Counter(every))
count1 = count1.most_common()

count2 = collections.Counter()
for idx, i in enumerate(A[:,2]):
    x = collections.Counter([l.lower() for l in i])
    count2 += x
count2 = count2.most_common()



count3 = count0 + count1 + count2

# %%
badwords = ['the','in','a','of','for','and','an','to']
count4 = []
for idx,i in enumerate(count3):
    coun = 0
    for idj,j in enumerate(i[0]):
        if j in badwords:
            break
        else:
            coun+=1
    if coun == len(i[0]):
        count4.append(i)

# %%
count4
# Out:
# [(('environmental', 'flow'), 48),
#  (('environmental', 'flows'), 42),
#  (('river', 'basin'), 14),
#  (('instream', 'flow'), 14),
#  (('case', 'study'), 12),
#  (('flow', 'regimes'), 12),
#  (('flow', 'regime'), 11),
#  (('flow', 'requirements'), 11),
#  (('environmental', 'water'), 7),
#  (('flow', 'assessment'), 6),
#  (('hydrologic', 'alteration'), 5),
#  (('environmental', 'flow', 'requirements'), 5),
#  (('environmental', 'flow', 'regimes'), 5),
#  (('environmental', 'flow', 'assessment'), 5),
#  (('flow–ecology', 'relationships'), 5),
#  (('regional', 'scale'), 4),
#  (('natural', 'flow'), 4),
#  (('flow', 'management'), 4),
#  (('victoria', 'australia'), 4),
#  (('incremental', 'methodology'), 4),
#  (('flow', 'needs'), 4),
#  (('minimum', 'environmental'), 4),
#  (('instream', 'flow', 'requirements'), 4),
#  (('minimum', 'flow'), 4),
#  (('ecological', 'flow'), 4),
#  (('fish', 'species'), 4),
#  (('water', 'management'), 4),
#  (('eloha', 'framework'), 3),
#  (('flow-ecology', 'relationships'), 3),
#  (('determining', 'environmental'), 3),
#  (('determining', 'environmental', 'flows'), 3),
#  (('flow', 'restoration'), 3),
#  (('fish', 'assemblages'), 3),
#  (('zambezi', 'river'), 3),
#  (('fish', 'assemblage'), 3),
#  (('united', 'states'), 3),
#  (('environmental', 'flow', 'release'), 3),
#  (('flow', 'release'), 3),
#  (('instream', 'flows'), 3),
#  (('water', 'requirements'), 3),
#  (('environmental', 'flow', 'regime'), 3),
#  (('benthic', 'macroinvertebrates'), 3),
#  (('on', 'brown'), 3),
#  (('on', 'brown', 'trout'), 3),
#  (('brown', 'trout'), 3),
#  (('flow', 'methods'), 3),
#  (('instream', 'flow', 'incremental'), 3),
#  (('instream', 'flow', 'incremental', 'methodology'), 3),
#  (('flow', 'incremental'), 3),
#  (('flow', 'incremental', 'methodology'), 3),
#  (('british', 'columbia'), 3),
#  (('rivers', 'using'), 3),
#  (('based', 'on'), 3),
#  (('fish', 'populations'), 3),
#  (('surface', 'water'), 3),
#  (('assessing', 'environmental'), 3),
#  (('flow', 'recommendations'), 3),
#  (('environmental', 'flows', 'at'), 2),
#  (('flows', 'at'), 2),
#  (('regional', 'scale', 'application'), 2),
#  (('scale', 'application'), 2),
#  (('regulated', 'rivers'), 2),
#  (('regional', 'flow-ecology'), 2),
#  (('regional', 'flow-ecology', 'relationships'), 2),
#  (('california', 'usa'), 2),
#  (('flow', 'methodologies'), 2),
#  (('ecological', 'limits'), 2),
#  (('hydrologic', 'alteration', '('), 2),
#  (('hydrologic', 'alteration', '(', 'eloha'), 2),
#  (('alteration', '('), 2),
#  (('alteration', '(', 'eloha'), 2),
#  (('alteration', '(', 'eloha', ')'), 2),
#  (('(', 'eloha'), 2),
#  (('(', 'eloha', ')'), 2),
#  (('eloha', ')'), 2),
#  (('bayesian', 'network'), 2),
#  (('environmental', 'flow', 'restoration'), 2),
#  (('river', 'australia'), 2),
#  (('environmental', 'flow', 'scenarios'), 2),
#  (('flow', 'scenarios'), 2),
#  (('coordinated', 'operation'), 2),
#  (('zambezi', 'river', 'basin'), 2),
#  (('natural', 'flow', 'regimes'), 2),
#  (('temporal', 'scales'), 2),
#  (('hydrological', 'regimes'), 2),
#  (('lessons', 'learned'), 2),
#  (('river', 'case'), 2),
#  (('river', 'case', 'study'), 2),
#  (('fish', 'assemblage', 'structure'), 2),
#  (('assemblage', 'structure'), 2),
#  (('environmental', 'flow', 'management'), 2),
#  (('river', 'victoria'), 2),
#  (('river', 'victoria', 'australia'), 2),
#  (('invertebrate', 'community'), 2),
#  (('regulated', 'river'), 2),
#  (('recommending', 'instream'), 2),
#  (('recommending', 'instream', 'flows'), 2),
#  (('water', 'quantity'), 2),
#  (('water', 'quantity', 'needs'), 2),
#  (('quantity', 'needs'), 2),
#  (('environmental', 'water', 'requirements'), 2),
#  (('environmental', 'flow', 'standards'), 2),
#  (('flow', 'standards'), 2),
#  (('instream', 'habitat'), 2),
#  (('hydroelectric', 'dam'), 2),
#  (('downstream', 'from'), 2),
#  (('floodplain', 'wetlands'), 2),
#  (('ecological', 'consequences'), 2),
#  (('lowland', 'streams'), 2),
#  (('freshwater', 'fish'), 2),
#  (('macquarie', 'marshes'), 2),
#  (('natural', 'flow', 'regime'), 2),
#  (('salmo', 'trutta'), 2),
#  (('river', 'spöl'), 2),
#  (('national', 'park'), 2),
#  (('fish', 'community'), 2),
#  (('instream', 'flow', 'methods'), 2),
#  (('impact', 'assessment'), 2),
#  (('river', 'northern'), 2),
#  (('great', 'plains'), 2),
#  (('adaptive', 'management'), 2),
#  (('ecologically', 'acceptable'), 2),
#  (('broken', 'river'), 2),
#  (('hydrologically', 'based'), 2),
#  (('habitat', 'modelling'), 2),
#  (('river', 'flow'), 2),
#  (('minimum', 'instream'), 2),
#  (('minimum', 'instream', 'flow'), 2),
#  (('streams', 'from'), 2),
#  (('california', 'environmental'), 2),
#  (('california', 'environmental', 'flows'), 2),
#  (('california', 'environmental', 'flows', 'framework'), 2),
#  (('environmental', 'flows', 'framework'), 2),
#  (('flows', 'framework'), 2),
#  (('ecological', 'flow', 'needs'), 2),
#  (('example', 'from'), 2),
#  (('implementing', 'environmental'), 2),
#  (('implementing', 'environmental', 'flows'), 2),
#  (('unregulated', 'rivers'), 2),
#  (('hydrodynamic', 'habitat'), 2),
#  (('integrated', 'water'), 2),
#  (('integrated', 'water', 'management'), 2),
#  (('on', 'flow'), 2),
#  (('on', 'fish'), 2),
#  (('environmental', 'flow', 'assessments'), 2),
#  (('flow', 'assessments'), 2),
#  (('define', 'environmental'), 2),
#  (('assessing', 'environmental', 'flow'), 2),
#  (('designing', 'flows'), 2),
#  (('ecosystem', 'functioning'), 2),
#  (('on', 'aquatic'), 2),
#  (('riverine', 'fish'), 2),
#  (('climate', 'change'), 2),
#  (('climate', 'change', 'scenarios'), 2),
#  (('change', 'scenarios'), 2),
#  (('minimum', 'environmental', 'flows'), 2),
#  (('flow', 'targets'), 2),
#  (('decision', 'making'), 2),
#  (('comparing', 'environmental'), 2),
#  (('comparing', 'environmental', 'flow'), 2),
#  (('habitat', 'models'), 2),
#  (('developing', 'environmental'), 2),
#  (('southern', 'california'), 2),
#  (('instream-flow', 'analysis'), 1),
#  (('luquillo', 'experimental'), 1),
#  (('luquillo', 'experimental', 'forest'), 1),
#  (('luquillo', 'experimental', 'forest', 'puerto'), 1),
#  (('experimental', 'forest'), 1),
#  (('experimental', 'forest', 'puerto'), 1),
#  (('experimental', 'forest', 'puerto', 'rico'), 1),
#  (('forest', 'puerto'), 1),
#  (('forest', 'puerto', 'rico'), 1),
#  (('forest', 'puerto', 'rico', 'methods'), 1),
#  (('puerto', 'rico'), 1),
#  (('puerto', 'rico', 'methods'), 1),
#  (('rico', 'methods'), 1),
#  (('basic', 'tools'), 1),
#  (('setting', 'environmental'), 1),
#  (('setting', 'environmental', 'flows'), 1),
#  (('setting', 'environmental', 'flows', 'at'), 1),
#  (('mediterranean', 'river'), 1),
#  (('mediterranean', 'river', 'basin'), 1),
#  (('balancing', 'water'), 1),
#  (('balancing', 'water', 'reuse'), 1),
#  (('water', 'reuse'), 1),
#  (('ecological', 'support'), 1),
#  (('ecological', 'support', 'goals'), 1),
#  (('support', 'goals'), 1),
#  (('effluent', 'dominated'), 1),
#  (('effluent', 'dominated', 'river'), 1),
#  (('dominated', 'river'), 1),
#  (('associating', 'metrics'), 1),
#  (('hydrologic', 'variability'), 1),
#  (('hydrologic', 'variability', 'with'), 1),
#  (('hydrologic', 'variability', 'with', 'benthic'), 1),
#  (('variability', 'with'), 1),
#  (('variability', 'with', 'benthic'), 1),
#  (('variability', 'with', 'benthic', 'macroinvertebrate'), 1),
#  (('with', 'benthic'), 1),
#  (('with', 'benthic', 'macroinvertebrate'), 1),
#  (('with', 'benthic', 'macroinvertebrate', 'communities'), 1),
#  (('benthic', 'macroinvertebrate'), 1),
#  (('benthic', 'macroinvertebrate', 'communities'), 1),
#  (('macroinvertebrate', 'communities'), 1),
#  (('unregulated', 'snowmelt-dominated'), 1),
#  (('unregulated', 'snowmelt-dominated', 'rivers'), 1),
#  (('snowmelt-dominated', 'rivers'), 1),
#  (('upper', 'tennessee'), 1),
#  (('upper', 'tennessee', 'river'), 1),
#  (('upper', 'tennessee', 'river', 'basin'), 1),
#  (('tennessee', 'river'), 1),
#  (('tennessee', 'river', 'basin'), 1),
#  (('inform', 'watershed'), 1),
#  (('inform', 'watershed', 'management'), 1),
#  (('inform', 'watershed', 'management', 'decisions'), 1),
#  (('watershed', 'management'), 1),
#  (('watershed', 'management', 'decisions'), 1),
#  (('watershed', 'management', 'decisions', 'application'), 1),
#  (('management', 'decisions'), 1),
#  (('management', 'decisions', 'application'), 1),
#  (('decisions', 'application'), 1),
#  (('san', 'diego'), 1),
#  (('san', 'diego', 'river'), 1),
#  (('san', 'diego', 'river', 'watershed'), 1),
#  (('diego', 'river'), 1),
#  (('diego', 'river', 'watershed'), 1),
#  (('diego', 'river', 'watershed', 'california'), 1),
#  (('river', 'watershed'), 1),
#  (('river', 'watershed', 'california'), 1),
#  (('river', 'watershed', 'california', 'usa'), 1),
#  (('watershed', 'california'), 1),
#  (('watershed', 'california', 'usa'), 1),
#  (('multiscale', 'environmental'), 1),
#  (('multiscale', 'environmental', 'flow'), 1),
#  (('multiscale', 'environmental', 'flow', 'methodologies'), 1),
#  (('environmental', 'flow', 'methodologies'), 1),
#  (('environmental', 'flow', 'methodologies', 'as'), 1),
#  (('flow', 'methodologies', 'as'), 1),
#  (('flow', 'methodologies', 'as', 'tools'), 1),
#  (('methodologies', 'as'), 1),
#  (('methodologies', 'as', 'tools'), 1),
#  (('as', 'tools'), 1),
#  (('optimized', 'management'), 1),
#  (('norwegian', 'regulated'), 1),
#  (('norwegian', 'regulated', 'national'), 1),
#  (('norwegian', 'regulated', 'national', 'salmon'), 1),
#  (('regulated', 'national'), 1),
#  (('regulated', 'national', 'salmon'), 1),
#  (('regulated', 'national', 'salmon', 'watercourse'), 1),
#  (('national', 'salmon'), 1),
#  (('national', 'salmon', 'watercourse'), 1),
#  (('salmon', 'watercourse'), 1),
#  (('(', 'eloha', ')', 'method'), 1),
#  (('eloha', ')', 'method'), 1),
#  ((')', 'method'), 1),
#  (('potomac', 'river'), 1),
#  (('potomac', 'river', 'basin'), 1),
#  (('potomac', 'river', 'basin', 'usa'), 1),
#  (('river', 'basin', 'usa'), 1),
#  (('basin', 'usa'), 1),
#  (('bayesian', 'network', 'approach'), 1),
#  (('network', 'approach'), 1),
#  (('support', 'environmental'), 1),
#  (('support', 'environmental', 'flow'), 1),
#  (('support', 'environmental', 'flow', 'restoration'), 1),
#  (('environmental', 'flow', 'restoration', 'decisions'), 1),
#  (('flow', 'restoration', 'decisions'), 1),
#  (('restoration', 'decisions'), 1),
#  (('yarra', 'river'), 1),
#  (('yarra', 'river', 'australia'), 1),
#  (('using', 'regional'), 1),
#  (('using', 'regional', 'scale'), 1),
#  (('using', 'regional', 'scale', 'flow-ecology'), 1),
#  (('regional', 'scale', 'flow-ecology'), 1),
#  (('regional', 'scale', 'flow-ecology', 'modeling'), 1),
#  (('scale', 'flow-ecology'), 1),
#  (('scale', 'flow-ecology', 'modeling'), 1),
#  (('flow-ecology', 'modeling'), 1),
#  (('identify', 'catchments'), 1),
#  (('identify', 'catchments', 'where'), 1),
#  (('identify', 'catchments', 'where', 'fish'), 1),
#  (('catchments', 'where'), 1),
#  (('catchments', 'where', 'fish'), 1),
#  (('catchments', 'where', 'fish', 'assemblages'), 1),
#  (('where', 'fish'), 1),
#  (('where', 'fish', 'assemblages'), 1),
#  (('where', 'fish', 'assemblages', 'are'), 1),
#  (('fish', 'assemblages', 'are'), 1),
#  (('fish', 'assemblages', 'are', 'most'), 1),
#  (('assemblages', 'are'), 1),
#  (('assemblages', 'are', 'most'), 1),
#  (('assemblages', 'are', 'most', 'vulnerable'), 1),
#  (('are', 'most'), 1),
#  (('are', 'most', 'vulnerable'), 1),
#  (('most', 'vulnerable'), 1),
#  (('water', 'availability'), 1),
#  (('environmental', 'flow', 'monitoring'), 1),
#  (('flow', 'monitoring'), 1),
#  (('sustainable', 'rivers'), 1),
#  (('sustainable', 'rivers', 'project'), 1),
#  (('sustainable', 'rivers', 'project', 'on'), 1),
#  (('rivers', 'project'), 1),
#  (('rivers', 'project', 'on'), 1),
#  (('project', 'on'), 1),
#  (('middle', 'fork'), 1),
#  (('middle', 'fork', 'willamette'), 1),
#  (('fork', 'willamette'), 1),
#  (('mckenzie', 'rivers'), 1),
#  (('mckenzie', 'rivers', 'western'), 1),
#  (('mckenzie', 'rivers', 'western', 'oregon'), 1),
#  (('rivers', 'western'), 1),
#  (('rivers', 'western', 'oregon'), 1),
#  (('rivers', 'western', 'oregon', '2014–15'), 1),
#  (('western', 'oregon'), 1),
#  (('western', 'oregon', '2014–15'), 1),
#  (('oregon', '2014–15'), 1),
#  (('managing', 'hydropower'), 1),
#  (('managing', 'hydropower', 'dam'), 1),
#  (('managing', 'hydropower', 'dam', 'releases'), 1),
#  (('hydropower', 'dam'), 1),
#  (('hydropower', 'dam', 'releases'), 1),
#  (('dam', 'releases'), 1),
#  (('water', 'users'), 1),
#  (('imperiled', 'fishes'), 1),
#  (('imperiled', 'fishes', 'with'), 1),
#  (('imperiled', 'fishes', 'with', 'contrasting'), 1),
#  (('fishes', 'with'), 1),
#  (('fishes', 'with', 'contrasting'), 1),
#  (('fishes', 'with', 'contrasting', 'thermal'), 1),
#  (('with', 'contrasting'), 1),
#  (('with', 'contrasting', 'thermal'), 1),
#  (('with', 'contrasting', 'thermal', 'habitat'), 1),
#  (('contrasting', 'thermal'), 1),
#  (('contrasting', 'thermal', 'habitat'), 1),
#  (('contrasting', 'thermal', 'habitat', 'requirements'), 1),
#  (('thermal', 'habitat'), 1),
#  (('thermal', 'habitat', 'requirements'), 1),
#  (('habitat', 'requirements'), 1),
#  (('environmental', 'flow', 'scenarios', 'using'), 1),
#  (('flow', 'scenarios', 'using'), 1),
#  (('flow', 'scenarios', 'using', 'state-and-transition'), 1),
#  (('scenarios', 'using'), 1),
#  (('scenarios', 'using', 'state-and-transition'), 1),
#  (('scenarios', 'using', 'state-and-transition', 'models'), 1),
#  (('using', 'state-and-transition'), 1),
#  (('using', 'state-and-transition', 'models'), 1),
#  (('state-and-transition', 'models'), 1),
#  (('flow', 'regime', 'through'), 1),
#  (('regime', 'through'), 1),
#  (('multireservoir', 'system'), 1),
#  (('optimizing', 'environmental'), 1),
#  (('optimizing', 'environmental', 'flows'), 1),
#  (('multiple', 'reaches'), 1),
#  (('multiple', 'reaches', 'affected'), 1),
#  (('multiple', 'reaches', 'affected', 'by'), 1),
#  (('reaches', 'affected'), 1),
#  (('reaches', 'affected', 'by'), 1),
#  (('affected', 'by'), 1),
#  (('multipurpose', 'reservoir'), 1),
#  (('multipurpose', 'reservoir', 'system'), 1),
#  (('reservoir', 'system'), 1),
#  (('taiwan', 'restoring'), 1),
#  (('taiwan', 'restoring', 'natural'), 1),
#  (('taiwan', 'restoring', 'natural', 'flow'), 1),
#  (('restoring', 'natural'), 1),
#  (('restoring', 'natural', 'flow'), 1),
#  (('restoring', 'natural', 'flow', 'regimes'), 1),
#  (('natural', 'flow', 'regimes', 'at'), 1),
#  (('flow', 'regimes', 'at'), 1),
#  (('flow', 'regimes', 'at', 'multiple'), 1),
#  (('regimes', 'at'), 1),
#  (('regimes', 'at', 'multiple'), 1),
#  (('regimes', 'at', 'multiple', 'temporal'), 1),
#  (('at', 'multiple'), 1),
#  (('at', 'multiple', 'temporal'), 1),
#  (('at', 'multiple', 'temporal', 'scales'), 1),
#  (('multiple', 'temporal'), 1),
#  (('multiple', 'temporal', 'scales'), 1),
#  (('physical', 'drivers'), 1),
#  (('physical', 'drivers', 'on'), 1),
#  (('physical', 'drivers', 'on', 'fisheries'), 1),
#  (('drivers', 'on'), 1),
#  (('drivers', 'on', 'fisheries'), 1),
#  (('drivers', 'on', 'fisheries', 'productivity'), 1),
#  (('on', 'fisheries'), 1),
#  (('on', 'fisheries', 'productivity'), 1),
#  (('on', 'fisheries', 'productivity', 'metrics'), 1),
#  (('fisheries', 'productivity'), 1),
#  (('fisheries', 'productivity', 'metrics'), 1),
#  (('fisheries', 'productivity', 'metrics', 'across'), 1),
#  (('productivity', 'metrics'), 1),
#  (('productivity', 'metrics', 'across'), 1),
#  (('productivity', 'metrics', 'across', 'rivers'), 1),
#  (('metrics', 'across'), 1),
#  (('metrics', 'across', 'rivers'), 1),
#  (('across', 'rivers'), 1),
#  (('varying', 'hydrological'), 1),
#  (('varying', 'hydrological', 'regimes'), 1),
#  (('varying', 'hydrological', 'regimes', 'lessons'), 1),
#  (('hydrological', 'regimes', 'lessons'), 1),
#  (('hydrological', 'regimes', 'lessons', 'learned'), 1),
#  (('regimes', 'lessons'), 1),
#  (('regimes', 'lessons', 'learned'), 1),
#  (('regimes', 'lessons', 'learned', 'from'), 1),
#  (('lessons', 'learned', 'from'), 1),
#  (('lessons', 'learned', 'from', 'nserc'), 1),
#  (('learned', 'from'), 1),
#  (('learned', 'from', 'nserc'), 1),
#  (('learned', 'from', 'nserc', 'hydronet'), 1),
#  (('from', 'nserc'), 1),
#  (('from', 'nserc', 'hydronet'), 1),
#  (('from', 'nserc', 'hydronet', '2009-2015'), 1),
#  (('nserc', 'hydronet'), 1),
#  (('nserc', 'hydronet', '2009-2015'), 1),
#  (('hydronet', '2009-2015'), 1),
#  (('identifying', 'cultural'), 1),
#  (('identifying', 'cultural', 'flow'), 1),
#  (('identifying', 'cultural', 'flow', 'preferences'), 1),
#  (('cultural', 'flow'), 1),
#  (('cultural', 'flow', 'preferences'), 1),
#  (('cultural', 'flow', 'preferences', 'kakaunui'), 1),
#  (('flow', 'preferences'), 1),
#  (('flow', 'preferences', 'kakaunui'), 1),
#  (('flow', 'preferences', 'kakaunui', 'river'), 1),
#  (('preferences', 'kakaunui'), 1),
#  (('preferences', 'kakaunui', 'river'), 1),
#  (('preferences', 'kakaunui', 'river', 'case'), 1),
#  (('kakaunui', 'river'), 1),
#  (('kakaunui', 'river', 'case'), 1),
#  (('kakaunui', 'river', 'case', 'study'), 1),
#  (('environmental', 'thresholds'), 1),
#  (('stream', 'fish'), 1),
#  (('stream', 'fish', 'assemblage'), 1),
#  (('stream', 'fish', 'assemblage', 'structure'), 1),
#  (('fish', 'assemblage', 'structure', 'across'), 1),
#  (('assemblage', 'structure', 'across'), 1),
#  (('assemblage', 'structure', 'across', 'flow'), 1),
#  (('structure', 'across'), 1),
#  (('structure', 'across', 'flow'), 1),
#  (('structure', 'across', 'flow', 'regimes'), 1),
#  (('across', 'flow'), 1),
#  (('across', 'flow', 'regimes'), 1),
#  (('flow-recruitment', 'relationships'), 1),
#  (('shoal', 'chub'), 1),
#  (('shoal', 'chub', '('), 1),
#  (('shoal', 'chub', '(', 'macrhybopsis'), 1),
#  (('chub', '('), 1),
#  (('chub', '(', 'macrhybopsis'), 1),
#  (('chub', '(', 'macrhybopsis', 'hyostoma'), 1),
#  (('(', 'macrhybopsis'), 1),
#  (('(', 'macrhybopsis', 'hyostoma'), 1),
#  (('(', 'macrhybopsis', 'hyostoma', ')'), 1),
#  (('macrhybopsis', 'hyostoma'), 1),
#  (('macrhybopsis', 'hyostoma', ')'), 1),
#  (('hyostoma', ')'), 1),
#  (('managing', 'environmental'), 1),
#  (('managing', 'environmental', 'flows'), 1),
#  (('sustain', 'groundwater‐dominated'), 1),
#  (('sustain', 'groundwater‐dominated', 'stream'), 1),
#  (('sustain', 'groundwater‐dominated', 'stream', 'ecosystems'), 1),
#  (('groundwater‐dominated', 'stream'), 1),
#  (('groundwater‐dominated', 'stream', 'ecosystems'), 1),
#  (('stream', 'ecosystems'), 1),
#  (('environmental', 'flow', 'management', 'strategy'), 1),
#  (('flow', 'management', 'strategy'), 1),
#  (('management', 'strategy'), 1),
#  (('thomson', 'river'), 1),
#  (('thomson', 'river', 'victoria'), 1),
#  (('thomson', 'river', 'victoria', 'australia'), 1),
#  (('some', 'environmental'), 1),
#  (('some', 'environmental', 'aspects'), 1),
#  (('environmental', 'aspects'), 1),
#  (('water', 'supplies'), 1),
#  (('madrid', '-'), 1),
#  (('madrid', '-', 'cubillo'), 1),
#  (('madrid', '-', 'cubillo', '-'), 1),
#  (('-', 'cubillo'), 1),
#  (('-', 'cubillo', '-'), 1),
#  (('-', 'cubillo', '-', '1992'), 1),
#  (('cubillo', '-'), 1),
#  (('cubillo', '-', '1992'), 1),
#  (('cubillo', '-', '1992', '-'), 1),
#  (('-', '1992'), 1),
#  (('-', '1992', '-'), 1),
#  (('-', '1992', '-', 'water'), 1),
#  (('1992', '-'), 1),
#  (('1992', '-', 'water'), 1),
#  (('-', 'water'), 1),
#  (('environment', 'journal'), 1),
#  (('environment', 'journal', '-'), 1),
#  (('environment', 'journal', '-', 'wiley'), 1),
#  (('journal', '-'), 1),
#  (('journal', '-', 'wiley'), 1),
#  (('journal', '-', 'wiley', 'online'), 1),
#  (('-', 'wiley'), 1),
#  (('-', 'wiley', 'online'), 1),
#  (('-', 'wiley', 'online', 'library'), 1),
#  (('wiley', 'online'), 1),
#  (('wiley', 'online', 'library'), 1),
#  (('online', 'library'), 1),
#  (('evaluating', 'fine'), 1),
#  (('evaluating', 'fine', 'sediment'), 1),
#  (('evaluating', 'fine', 'sediment', 'mobilization'), 1),
#  (('fine', 'sediment'), 1),
#  (('fine', 'sediment', 'mobilization'), 1),
#  (('sediment', 'mobilization'), 1),
#  (('gravel‐bed', 'river'), 1),
#  (('gravel‐bed', 'river', 'using'), 1),
#  (('gravel‐bed', 'river', 'using', 'controlled'), 1),
#  (('river', 'using'), 1),
#  (('river', 'using', 'controlled'), 1),
#  (('river', 'using', 'controlled', 'reservoir'), 1),
#  (('using', 'controlled'), 1),
#  (('using', 'controlled', 'reservoir'), 1),
#  (('using', 'controlled', 'reservoir', 'releases'), 1),
#  (('controlled', 'reservoir'), 1),
#  (('controlled', 'reservoir', 'releases'), 1),
#  (('reservoir', 'releases'), 1),
#  (('experimental', 'ramping'), 1),
#  (('experimental', 'ramping', 'rate'), 1),
#  (('ramping', 'rate'), 1),
#  (('south', 'saskatchewan'), 1),
#  (('south', 'saskatchewan', 'river'), 1),
#  (('south', 'saskatchewan', 'river', 'basin'), 1),
#  (('saskatchewan', 'river'), 1),
#  (('saskatchewan', 'river', 'basin'), 1),
#  (('saskatchewan', 'river', 'basin', 'alberta'), 1),
#  (('river', 'basin', 'alberta'), 1),
#  (('river', 'basin', 'alberta', 'canada'), 1),
#  (('basin', 'alberta'), 1),
#  (('basin', 'alberta', 'canada'), 1),
#  (('alberta', 'canada'), 1),
#  (('instream', 'flow', 'methodologies'), 1),
#  (('desert', 'rivers'), 1),
#  (('mexico', 'synthesis'), 1),
#  (('available', 'data'), 1),
#  (('gap', 'analysis'), 1),
#  (('response', 'by'), 1),
#  (('response', 'by', 'fish'), 1),
#  (('response', 'by', 'fish', 'assemblages'), 1),
#  (('by', 'fish'), 1),
#  (('by', 'fish', 'assemblages'), 1),
#  (('temperate', 'coastal'), 1),
#  (('temperate', 'coastal', 'australian'), 1),
#  (('temperate', 'coastal', 'australian', 'river'), 1),
#  (('coastal', 'australian'), 1),
#  (('coastal', 'australian', 'river'), 1),
#  (('australian', 'river'), 1),
#  (('paired', 'catchment'), 1),
#  (('paired', 'catchment', 'analysis'), 1),
#  (('catchment', 'analysis'), 1),
#  (('ecosystem', 'metabolism'), 1),
#  (('ecosystem', 'metabolism', 'as'), 1),
#  (('ecosystem', 'metabolism', 'as', 'indicators'), 1),
#  (('metabolism', 'as'), 1),
#  (('metabolism', 'as', 'indicators'), 1),
#  (('as', 'indicators'), 1),
#  (('river', 'ecosystem'), 1),
#  (('river', 'ecosystem', 'response'), 1),
#  (('ecosystem', 'response'), 1),
#  (('flow-reduced', 'river'), 1),
#  (('environmental', 'flows', 'during'), 1),
#  (('environmental', 'flows', 'during', 'drought'), 1),
#  (('flows', 'during'), 1),
#  (('flows', 'during', 'drought'), 1),
#  (('during', 'drought'), 1),
#  (('two', 'australian'), 1),
#  (('two', 'australian', 'rivers'), 1),
#  (('australian', 'rivers'), 1),
#  (('multiple', 'lines'), 1),
#  (('beneficial', 'effects'), 1),
#  (('two', 'lowland'), 1),
#  (('two', 'lowland', 'rivers'), 1),
#  (('lowland', 'rivers'), 1),
#  (('five', 'instream'), 1),
#  (('five', 'instream', 'flow'), 1),
#  (('five', 'instream', 'flow', 'needs'), 1),
#  (('instream', 'flow', 'needs'), 1),
#  (('instream', 'flow', 'needs', 'methodologies'), 1),
#  (('flow', 'needs', 'methodologies'), 1),
#  (('needs', 'methodologies'), 1),
#  (('three', 'utah'), 1),
#  (('three', 'utah', 'trout'), 1),
#  (('three', 'utah', 'trout', 'streams'), 1),
#  (('utah', 'trout'), 1),
#  (('utah', 'trout', 'streams'), 1),
#  (('trout', 'streams'), 1),
#  (('environmental', 'flow', 'release', 'on'), 1),
#  (('flow', 'release', 'on'), 1),
#  (('flow', 'release', 'on', 'water'), 1),
#  (('release', 'on'), 1),
#  (('release', 'on', 'water'), 1),
#  (('release', 'on', 'water', 'quality'), 1),
#  (('on', 'water'), 1),
#  (('on', 'water', 'quality'), 1),
#  (('water', 'quality'), 1),
#  (('hyporheic', 'zone'), 1),
#  (('hunter', 'river'), 1),
#  (('hunter', 'river', 'australia'), 1),
#  (('lowland', 'river'), 1),
#  (('lowland', 'river', 'systems'), 1),
#  (('lowland', 'river', 'systems', 'on'), 1),
#  (('river', 'systems'), 1),
#  (('river', 'systems', 'on'), 1),
#  (('systems', 'on'), 1),
#  (('swan', 'coastal'), 1),
#  (('swan', 'coastal', 'plain'), 1),
#  (('coastal', 'plain'), 1),
#  (('basic', 'flow'), 1),
#  (('alternative', 'approach'), 1),
#  (('calculate', 'minimum'), 1),
#  (('calculate', 'minimum', 'environmental'), 1),
#  (('calculate', 'minimum', 'environmental', 'instream'), 1),
#  (('minimum', 'environmental', 'instream'), 1),
#  (('minimum', 'environmental', 'instream', 'flows'), 1),
#  (('environmental', 'instream'), 1),
#  (('environmental', 'instream', 'flows'), 1),
#  (('discharge', 'methods'), 1),
#  (('habitat', 'optimization'), 1),
#  (('protect', 'fish'), 1),
#  (('protect', 'fish', 'habitat'), 1),
#  (('fish', 'habitat'), 1),
#  (('texas', 'environmental'), 1),
#  (('texas', 'environmental', 'flow'), 1),
#  (('texas', 'environmental', 'flow', 'standards'), 1),
#  (('hydrology-based', 'environmental'), 1),
#  (('hydrology-based', 'environmental', 'flow'), 1),
#  (('hydrology-based', 'environmental', 'flow', 'regime'), 1),
#  (('environmental', 'flow', 'regime', 'methodology'), 1),
#  (('flow', 'regime', 'methodology'), 1),
#  (('regime', 'methodology'), 1),
#  (('river', 'allen'), 1),
#  (('river', 'allen', 'instream'), 1),
#  (('river', 'allen', 'instream', 'flow'), 1),
#  (('allen', 'instream'), 1),
#  (('allen', 'instream', 'flow'), 1),
#  (('allen', 'instream', 'flow', 'requirements'), 1),
#  (('report', 'on'), 1),
#  (('report', 'on', 'minimum'), 1),
#  (('report', 'on', 'minimum', 'flow'), 1),
#  (('on', 'minimum'), 1),
#  (('on', 'minimum', 'flow'), 1),
#  (('on', 'minimum', 'flow', 'requirements'), 1),
#  (('minimum', 'flow', 'requirements'), 1),
#  (('taranaki', 'rivers'), 1),
#  (('flow', 'regime', 'requirements'), 1),
#  (('flow', 'regime', 'requirements', 'river'), 1),
#  (('regime', 'requirements'), 1),
#  (('regime', 'requirements', 'river'), 1),
#  (('regime', 'requirements', 'river', 'darent'), 1),
#  (('requirements', 'river'), 1),
#  (('requirements', 'river', 'darent'), 1),
#  (('river', 'darent'), 1),
#  (('fish', 'feeding'), 1),
#  (('growth', 'after'), 1),
#  (('minimum', 'flow', 'below'), 1),
#  (('flow', 'below'), 1),
#  (('conowingo', 'dam'), 1),
#  (('preliminary', 'assessment'), 1),
#  (('relationship', 'between'), 1),
#  (('relationship', 'between', 'angling'), 1),
#  (('relationship', 'between', 'angling', 'quality'), 1),
#  (('between', 'angling'), 1),
#  (('between', 'angling', 'quality'), 1),
#  (('angling', 'quality'), 1),
#  (('flow', 'on'), 1),
#  (('lower', 'malmesbury'), 1),
#  (('lower', 'malmesbury', 'avon'), 1),
#  (('malmesbury', 'avon'), 1),
#  (('benthic', 'macroinvertebrates', 'by'), 1),
#  (('benthic', 'macroinvertebrates', 'by', 'minimum'), 1),
#  (('macroinvertebrates', 'by'), 1),
#  (('macroinvertebrates', 'by', 'minimum'), 1),
#  (('macroinvertebrates', 'by', 'minimum', 'flow'), 1),
#  (('by', 'minimum'), 1),
#  (('by', 'minimum', 'flow'), 1),
#  (('by', 'minimum', 'flow', 'from'), 1),
#  (('minimum', 'flow', 'from'), 1),
#  (('flow', 'from'), 1),
#  (('ecosystem', 'service'), 1),
#  (('ecosystem', 'service', 'values'), 1),
#  (('service', 'values'), 1),
#  (('baiyangdian', 'lake'), 1),
#  (('baiyangdian', 'lake', 'china'), 1),
#  (('lake', 'china'), 1),
#  (('cyclic', 'releases'), 1),
#  (('cyclic', 'releases', 'during'), 1),
#  (('releases', 'during'), 1),
#  (('low', 'flow'), 1),
#  (('low', 'flow', 'period'), 1),
#  (('flow', 'period'), 1),
#  (('mitta', 'mitta'), 1),
#  (('mitta', 'mitta', 'river'), 1),
#  (('mitta', 'mitta', 'river', 'victoria'), 1),
#  (('mitta', 'river'), 1),
#  (('mitta', 'river', 'victoria'), 1),
#  (('mitta', 'river', 'victoria', 'australia'), 1),
#  (('hydrologic', 'manipulations'), 1),
#  (('channelized', 'kissimmee'), 1),
#  (('channelized', 'kissimmee', 'river'), 1),
#  (('channelized', 'kissimmee', 'river', 'implications'), 1),
#  (('kissimmee', 'river'), 1),
#  (('kissimmee', 'river', 'implications'), 1),
#  (('river', 'implications'), 1),
#  (('warmwater', 'fish'), 1),
#  (('warmwater', 'fish', 'assemblage'), 1),
#  (('warmwater', 'fish', 'assemblage', 'after'), 1),
#  (('fish', 'assemblage', 'after'), 1),
#  (('assemblage', 'after'), 1),
#  (('minimum-flow', 'release'), 1),
#  (('minimum-flow', 'release', 'downstream'), 1),
#  (('minimum-flow', 'release', 'downstream', 'from'), 1),
#  (('release', 'downstream'), 1),
#  (('release', 'downstream', 'from'), 1),
#  (('invasive', 'native'), 1),
#  (('invasive', 'native', 'wetland'), 1),
#  (('invasive', 'native', 'wetland', 'plant'), 1),
#  (('native', 'wetland'), 1),
#  (('native', 'wetland', 'plant'), 1),
#  (('wetland', 'plant'), 1),
#  (('environmental', 'flows', 'implications'), 1),
#  (('flows', 'implications'), 1),
#  (('managing', 'regulated'), 1),
#  (('managing', 'regulated', 'floodplain'), 1),
#  (('managing', 'regulated', 'floodplain', 'ecosystems'), 1),
#  (('regulated', 'floodplain'), 1),
#  (('regulated', 'floodplain', 'ecosystems'), 1),
#  (('floodplain', 'ecosystems'), 1),
#  (('hydrologic', 'regime'), 1),
#  (('macrophyte', 'assemblages'), 1),
#  (('temporary', 'floodplain'), 1),
#  (('temporary', 'floodplain', 'wetlands'), 1),
#  (('temporary', 'floodplain', 'wetlands', 'implications'), 1),
#  (('floodplain', 'wetlands', 'implications'), 1),
#  (('wetlands', 'implications'), 1),
#  (('detecting', 'responses'), 1),
#  (('environmental', 'water', 'allocations'), 1),
#  (('water', 'allocations'), 1),
#  (('restoring', 'flow'), 1),
#  (('restoring', 'flow', 'intermittency'), 1),
#  (('flow', 'intermittency'), 1),
#  (('artificially', 'perennial'), 1),
#  (('artificially', 'perennial', 'lowland'), 1),
#  (('artificially', 'perennial', 'lowland', 'streams'), 1),
#  (('perennial', 'lowland'), 1),
#  (('perennial', 'lowland', 'streams'), 1),
#  (('perennial', 'lowland', 'streams', 'patterns'), 1),
#  (('lowland', 'streams', 'patterns'), 1),
#  (('streams', 'patterns'), 1),
#  (('predictions', 'from'), 1),
#  (('broken—boosey', 'creek'), 1),
#  (('broken—boosey', 'creek', 'system'), 1),
#  (('creek', 'system'), 1),
#  (('northern', 'victoria'), 1),
#  (('northern', 'victoria', 'australia'), 1),
#  (('small', 'environmental'), 1),
#  (('small', 'environmental', 'flows'), 1),
#  (('small', 'environmental', 'flows', 'drought'), 1),
#  (('environmental', 'flows', 'drought'), 1),
#  (('flows', 'drought'), 1),
#  (('macquarie', 'marshes', 'arid'), 1),
#  (('macquarie', 'marshes', 'arid', 'australia'), 1),
#  (('marshes', 'arid'), 1),
#  (('marshes', 'arid', 'australia'), 1),
#  (('arid', 'australia'), 1),
#  (('nonnative', 'fishes'), 1),
#  (('natural', 'flow', 'regime', 'mimicry'), 1),
#  (('flow', 'regime', 'mimicry'), 1),
#  (('regime', 'mimicry'), 1),
#  (('san', 'juan'), 1),
#  (('san', 'juan', 'river'), 1),
#  (('juan', 'river'), 1),
#  (('experimental', 'flooding'), 1),
#  (('experimental', 'flooding', 'on'), 1),
#  (('experimental', 'flooding', 'on', 'brown'), 1),
#  (('flooding', 'on'), 1),
#  (('flooding', 'on', 'brown'), 1),
#  (('flooding', 'on', 'brown', 'trout'), 1),
#  (('on', 'brown', 'trout', '('), 1),
#  (('brown', 'trout', '('), 1),
#  (('brown', 'trout', '(', 'salmo'), 1),
#  (('trout', '('), 1),
#  (('trout', '(', 'salmo'), 1),
#  (('trout', '(', 'salmo', 'trutta'), 1),
#  (('(', 'salmo'), 1),
#  (('(', 'salmo', 'trutta'), 1),
#  (('(', 'salmo', 'trutta', 'fario'), 1),
#  (('salmo', 'trutta', 'fario'), 1),
#  (('salmo', 'trutta', 'fario', 'l'), 1),
#  (('trutta', 'fario'), 1),
#  (('trutta', 'fario', 'l'), 1),
#  (('trutta', 'fario', 'l', ')'), 1),
#  (('fario', 'l'), 1),
#  (('fario', 'l', ')'), 1),
#  (('l', ')'), 1),
#  (('river', 'spöl', 'swiss'), 1),
#  (('river', 'spöl', 'swiss', 'national'), 1),
#  (('spöl', 'swiss'), 1),
#  (('spöl', 'swiss', 'national'), 1),
#  (('spöl', 'swiss', 'national', 'park'), 1),
#  (('swiss', 'national'), 1),
#  (('swiss', 'national', 'park'), 1),
#  (('restored', 'freshwater'), 1),
#  (('restored', 'freshwater', 'inflow'), 1),
#  (('restored', 'freshwater', 'inflow', 'on'), 1),
#  (('freshwater', 'inflow'), 1),
#  (('freshwater', 'inflow', 'on'), 1),
#  (('freshwater', 'inflow', 'on', 'macrofauna'), 1),
#  (('inflow', 'on'), 1),
#  (('inflow', 'on', 'macrofauna'), 1),
#  (('on', 'macrofauna'), 1),
#  (('upper', 'rincon'), 1),
#  (('upper', 'rincon', 'bayou'), 1),
#  (('upper', 'rincon', 'bayou', 'texas'), 1),
#  (('rincon', 'bayou'), 1),
#  (('rincon', 'bayou', 'texas'), 1),
#  (('rincon', 'bayou', 'texas', 'usa'), 1),
#  (('bayou', 'texas'), 1),
#  (('bayou', 'texas', 'usa'), 1),
#  (('texas', 'usa'), 1),
#  (('ecological', 'effects'), 1),
#  (('long-term', 'flood'), 1),
#  (('long-term', 'flood', 'program'), 1),
#  (('flood', 'program'), 1),
#  (('flow-regulated', 'river'), 1),
#  (('fish', 'community', 'changes'), 1),
#  (('fish', 'community', 'changes', 'after'), 1),
#  (('community', 'changes'), 1),
#  (('community', 'changes', 'after'), 1),
#  (('community', 'changes', 'after', 'minimum'), 1),
#  (('changes', 'after'), 1),
#  (('changes', 'after', 'minimum'), 1),
#  (('changes', 'after', 'minimum', 'flow'), 1),
#  (('after', 'minimum'), 1),
#  (('after', 'minimum', 'flow'), 1),
#  (('after', 'minimum', 'flow', 'increase'), 1),
#  (('minimum', 'flow', 'increase'), 1),
#  (('minimum', 'flow', 'increase', 'testing'), 1),
#  (('flow', 'increase'), 1),
#  (('flow', 'increase', 'testing'), 1),
#  (('flow', 'increase', 'testing', 'quantitative'), 1),
#  (('increase', 'testing'), 1),
#  (('increase', 'testing', 'quantitative'), 1),
#  (('increase', 'testing', 'quantitative', 'predictions'), 1),
#  (('testing', 'quantitative'), 1),
#  (('testing', 'quantitative', 'predictions'), 1),
#  (('quantitative', 'predictions'), 1),
#  (('rhône', 'river'), 1),
#  (('rhône', 'river', 'at'), 1),
#  (('rhône', 'river', 'at', 'pierre-bénite'), 1),
#  (('river', 'at'), 1),
#  (('river', 'at', 'pierre-bénite'), 1),
#  (('river', 'at', 'pierre-bénite', 'france'), 1),
#  (('at', 'pierre-bénite'), 1),
#  (('at', 'pierre-bénite', 'france'), 1),
#  (('pierre-bénite', 'france'), 1),
#  (('relative', 'bias'), 1),
#  (('several', 'fisheries'), 1),
#  (('several', 'fisheries', 'instream'), 1),
#  (('several', 'fisheries', 'instream', 'flow'), 1),
#  (('fisheries', 'instream'), 1),
#  (('fisheries', 'instream', 'flow'), 1),
#  (('fisheries', 'instream', 'flow', 'methods'), 1),
#  (('brisbane', 'river'), 1),
#  (('brisbane', 'river', 'downstream'), 1),
#  (('brisbane', 'river', 'downstream', 'from'), 1),
#  (('river', 'downstream'), 1),
#  (('river', 'downstream', 'from'), 1),
#  (('river', 'downstream', 'from', 'wivenhoe'), 1),
#  (('downstream', 'from', 'wivenhoe'), 1),
#  (('downstream', 'from', 'wivenhoe', 'dam'), 1),
#  (('from', 'wivenhoe'), 1),
#  (('from', 'wivenhoe', 'dam'), 1),
#  (('wivenhoe', 'dam'), 1),
#  (('new', 'perspectives'), 1),
#  (('ecological', 'flow', 'determination'), 1),
#  (('flow', 'determination'), 1),
#  (('semi-arid', 'regions'), 1),
#  (('preliminary', 'approach'), 1),
#  (('minimum', 'residual'), 1),
#  (('minimum', 'residual', 'flows'), 1),
#  (('residual', 'flows'), 1),
#  (('czech', 'republic'), 1),
#  (('field', 'testing'), 1),
#  (('measure', '``'), 1),
#  (('measure', '``', 'in-stream'), 1),
#  (('measure', '``', 'in-stream', "''"), 1),
#  (('``', 'in-stream'), 1),
#  (('``', 'in-stream', "''"), 1),
#  (('``', 'in-stream', "''", 'values'), 1),
#  (('in-stream', "''"), 1),
#  (('in-stream', "''", 'values'), 1),
#  (("''", 'values'), 1),
#  (('tongue', 'river'), 1),
#  (('tongue', 'river', 'northern'), 1),
#  (('tongue', 'river', 'northern', 'great'), 1),
#  (('river', 'northern', 'great'), 1),
#  (('river', 'northern', 'great', 'plains'), 1),
#  (('northern', 'great'), 1),
#  (('northern', 'great', 'plains'), 1),
#  (('northern', 'great', 'plains', '('), 1),
#  (('great', 'plains', '('), 1),
#  (('great', 'plains', '(', 'ngp'), 1),
#  (('plains', '('), 1),
#  (('plains', '(', 'ngp'), 1),
#  (('plains', '(', 'ngp', ')'), 1),
#  (('(', 'ngp'), 1),
#  (('(', 'ngp', ')'), 1),
#  (('(', 'ngp', ')', 'region'), 1),
#  (('ngp', ')'), 1),
#  (('ngp', ')', 'region'), 1),
#  (('ngp', ')', 'region', 'executive'), 1),
#  ((')', 'region'), 1),
#  ((')', 'region', 'executive'), 1),
#  ((')', 'region', 'executive', 'summary'), 1),
#  (('region', 'executive'), 1),
#  (('region', 'executive', 'summary'), 1),
#  (('executive', 'summary'), 1),
#  (('history', 'rationale'), 1),
#  (('lessons', 'learned', 'thresholds'), 1),
#  (('learned', 'thresholds'), 1),
#  (('potential', 'concern'), 1),
#  (('kruger', 'national'), 1),
#  (('kruger', 'national', 'park'), 1),
#  (('kruger', 'national', 'park', 'river'), 1),
#  (('national', 'park', 'river'), 1),
#  (('national', 'park', 'river', 'adaptive'), 1),
#  (('park', 'river'), 1),
#  (('park', 'river', 'adaptive'), 1),
#  (('park', 'river', 'adaptive', 'management'), 1),
#  (('river', 'adaptive'), 1),
#  (('river', 'adaptive', 'management'), 1),
#  (('benthic', 'invertebrate'), 1),
#  (('benthic', 'invertebrate', 'production'), 1),
#  (('invertebrate', 'production'), 1),
#  (('ecologically', 'acceptable', 'flows'), 1),
#  (('acceptable', 'flows'), 1),
#  (('aquatic', 'ecology'), 1),
#  (('two', 'british'), 1),
#  (('two', 'british', 'rivers'), 1),
#  (('two', 'british', 'rivers', 'application'), 1),
#  (('british', 'rivers'), 1),
#  (('british', 'rivers', 'application'), 1),
#  (('rivers', 'application'), 1),
#  (('flow', 'incremental', 'methodology', 'using'), 1),
#  (('incremental', 'methodology', 'using'), 1),
#  (('methodology', 'using'), 1),
#  (('phabsim', 'system'), 1),
#  (('broken', 'river', 'scientific'), 1),
#  (('broken', 'river', 'scientific', 'panel'), 1),
#  (('river', 'scientific'), 1),
#  (('river', 'scientific', 'panel'), 1),
#  (('river', 'scientific', 'panel', 'on'), 1),
#  (('scientific', 'panel'), 1),
#  (('scientific', 'panel', 'on'), 1),
#  (('panel', 'on'), 1),
#  (('environmental', 'condition'), 1),
#  (('broken', 'creek'), 1),
#  (('minimum', 'acceptable'), 1),
#  (('minimum', 'acceptable', 'stream'), 1),
#  (('minimum', 'acceptable', 'stream', 'flows'), 1),
#  (('acceptable', 'stream'), 1),
#  (('acceptable', 'stream', 'flows'), 1),
#  (('stream', 'flows'), 1),
#  (('hydrologically', 'based', 'instream'), 1),
#  (('hydrologically', 'based', 'instream', 'flow'), 1),
#  (('based', 'instream'), 1),
#  (('based', 'instream', 'flow'), 1),
#  (('based', 'instream', 'flow', 'techniques'), 1),
#  (('instream', 'flow', 'techniques'), 1),
#  (('flow', 'techniques'), 1),
#  (('atlantic', 'canada'), 1),
#  (('salmonid', 'habitat'), 1),
#  (('salmonid', 'habitat', 'modelling'), 1),
#  (('salmonid', 'habitat', 'modelling', 'studies'), 1),
#  (('habitat', 'modelling', 'studies'), 1),
#  (('modelling', 'studies'), 1),
#  (('their', 'contribution'), 1),
#  (('ecologically', 'acceptable', 'release'), 1),
#  (('ecologically', 'acceptable', 'release', 'policy'), 1),
#  (('acceptable', 'release'), 1),
#  (('acceptable', 'release', 'policy'), 1),
#  (('release', 'policy'), 1),
#  (('kielder', 'reservoir'), 1),
#  (('kielder', 'reservoir', 'north-east'), 1),
#  (('kielder', 'reservoir', 'north-east', 'england'), 1),
#  (('reservoir', 'north-east'), 1),
#  (('reservoir', 'north-east', 'england'), 1),
#  (('north-east', 'england'), 1),
#  (('environmental', 'flows', 'assessment'), 1),
#  (('flows', 'assessment'), 1),
#  (('macroinvertebrates', 'at'), 1),
#  (('river', 'reach'), 1),
#  (('river', 'reach', 'scale'), 1),
#  (('reach', 'scale'), 1),
#  (('different', 'degrees'), 1),
#  (('hydromorphological', 'alteration'), 1),
#  (('river', 'flow', 'indexing'), 1),
#  (('river', 'flow', 'indexing', 'using'), 1),
#  (('flow', 'indexing'), 1),
#  ...]
